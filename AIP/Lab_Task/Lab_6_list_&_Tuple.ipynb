# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-family: 'Arial Black', Gadget, sans-serif; color: #2c3e50; font-size: 32px; text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.2);">University of Engineering And Technology Peshawar</span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-family: 'Georgia', serif; color: #8e44ad; font-size: 28px;">Jalozai Campus</span>
# </div>

# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border: 2px solid #333;
#         border-radius: 15px;
#         background: #ffffff;
#         max-width: 700px;
#         box-shadow: 0 6px 15px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 28px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#         "
#     >
#         Course Title
#     </h1>
#     <h2
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 10px;
#         "
#     >
#         Introduction To AI Programming
#     </h2>
# </div

# %% [markdown]
# ### 📋 <span style="color: #34495e;">Lab Information</span>
#
# - **Lab No.**: <span style="color: #e74c3c;">5</span>
# - **Lab Title**: <span style="color: #2980b9;">Frequently used Method</span>
#
# ### 🙋‍♂️ <span style="color: #34495e;">Submitted By</span>
#
# - **Name**: <span style="color: #2980b9;">Aizaz Ali</span>
# - **Roll No.**: <span style="color: #e74c3c;">24JZELE0558</span>
# - **Section**: <span style="color: #16a085;">B</span>
#
# ---

# %% [markdown]
# _________

# %% [markdown]
# # Lab Report Tasks:

# %% [markdown]
# __________

# %% [markdown]
# ## Scenario:
# You are designing a small student management system. You need to maintain student data for a class. Each student has a name, a roll number, and a list of grades. The system must allow grade updates but keep roll numbers fixed.

# %% [markdown]
# _____________

# %% [markdown]
# `1.	Create a list of student names: ["Ali", "Usman", "Hassan", "Kamran"].`

# %%
student_names= ["Ali", "Usman", "Hassan", "Kamran"]

# %% [markdown]
# _________

# %% [markdown]
# `2.	Create a tuple of student roll numbers: (101, 102, 103, 104).`

# %%
student_roll_numbers= (101, 102, 103, 104)

# %% [markdown]
# ________________

# %% [markdown]
# `3.	For each student, create a list of grades (3 subjects) using nested lists:`
# `Example: [ [85, 90, 78], [88, 92, 80], ... ]`

# %%
list_of_grades=[[85, 90, 78], [88, 92, 80],[90,91,92],[67,87,56]]

# %% [markdown]
# _______________

# %% [markdown]
# `4.	Update Ali’s second grade to 95.`

# %%
list_of_grades[0][1]=95

# %%
list_of_grades
# Out:
# [[85, 95, 78], [88, 92, 80], [90, 91, 92], [67, 87, 56]]

# %% [markdown]
# ___________________

# %% [markdown]
# `5.	Add a new grade for Hassan in the fourth subject.`

# %%
list_of_grades[2].append(76)

# %%
list_of_grades
# Out:
# [[85, 95, 78], [88, 92, 80], [90, 91, 92, 76], [67, 87, 56], [2]]

# %% [markdown]
# _________________

# %% [markdown]
# `6.	Attempt to change Kamran’s roll number and observe what happens. Explain why.`

# %%
student_roll_numbers[3]=107
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 student_roll_numbers[3]=107
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# this give us an error. because the student rool numbers is a tuple and we does not change the touple. tuple is immutable.

# %% [markdown]
# _____________________

# %% [markdown]
# `7.	Print all students' names with their updated grades in a readable format.`

# %%
for S_N,S_G in zip(student_names,list_of_grades):
    print(F'Student Name: {S_N}, {S_N}  Grade is {S_G}')
# Out:
# Student Name: Ali, Ali  Grade is [85, 95, 78]
# Student Name: Usman, Usman  Grade is [88, 92, 80]
# Student Name: Hassan, Hassan  Grade is [90, 91, 92, 76]
# Student Name: Kamran, Kamran  Grade is [67, 87, 56]

# %% [markdown]
# ___________

# %% [markdown]
# _________________
